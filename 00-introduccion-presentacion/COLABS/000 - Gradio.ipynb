# %%
pip install gradio -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 MB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.2/322.2 kB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 57.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.6 MB/s eta 0:00:00

# %%
import gradio as gr

# %%
def bienvenida(name):
    return "Hola " + name


demo = gr.Interface(fn=bienvenida, inputs="text", outputs="text")

demo.launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://134976881020af5d8c.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://134976881020af5d8c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
def saludo(nombre, intensidad):
  return "Hola, " + nombre + "!" * int(intensidad)

# %%
demo = gr.Interface(
  fn=saludo,
  inputs=["text", "slider"],
  outputs=["text"],
)

demo.launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://3628992fe8ecb2c33b.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://3628992fe8ecb2c33b.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
def greet(name):
    return "Hello " + name


# We instantiate the Textbox class
textbox = gr.Textbox(label="Type your name here:", placeholder="John Doe", lines=2)

gr.Interface(fn=greet, inputs=textbox, outputs="text").launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://563ca17f551ee2bb1c.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://563ca17f551ee2bb1c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
from bs4 import BeautifulSoup

# %%
html = """
<html>
<head>
  <title>Mi Página de Ejemplo</title>
</head>
<body>
  <h1>Título Principal</h1>
  <p>Este es un párrafo.</p>
  <a href="https://www.ejemplo.com">Enlace a Ejemplo</a>
</body>
</html>
"""

# %%
soup = BeautifulSoup(html, 'html.parser') # Aquí se hace el parsing

print(soup) # Imprime todo el objeto BeautifulSoup
# Out:
# <html>
# <head>
# <title>Mi Página de Ejemplo</title>
# </head>
# <body>
# <h1>Título Principal</h1>
# <p>Este es un párrafo.</p>
# <a href="https://www.ejemplo.com">Enlace a Ejemplo</a>
# </body>
# </html>

# %%
titulo = soup.title
print(titulo)       # Imprime la etiqueta <title>
print(titulo.text)  # Imprime el texto dentro de la etiqueta <title>
# Out:
# <title>Mi Página de Ejemplo</title>
# Mi Página de Ejemplo
# <p>Este es un párrafo.</p>
# Este es un párrafo.

# %%
parrafo = soup.p
print(parrafo)      # Imprime la etiqueta <p>
print(parrafo.text) # Imprime el texto dentro de la etiqueta <p>
# Out:
# <p>Este es un párrafo.</p>
# Este es un párrafo.

# %%
html = """
<html><head><title>Mi Página de Ejemplo</title></head><body><h1>Título Principal</h1><p>Este es un párrafo.</p><a href="https://www.ejemplo.com">Enlace a Ejemplo</a></body></html>
"""

soup = BeautifulSoup(html, 'html.parser')

print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Mi Página de Ejemplo
#   </title>
#  </head>
#  <body>
#   <h1>
#    Título Principal
#   </h1>
#   <p>
#    Este es un párrafo.
#   </p>
#   <a href="https://www.ejemplo.com">
#    Enlace a Ejemplo
#   </a>
#  </body>
# </html>

# %%
html = """
<a href="https://www.ejemplo.com" class="enlace-principal">Enlace a Ejemplo</a>
"""

soup = BeautifulSoup(html, 'html.parser')

enlace = soup.a
print(enlace['href'])   # Imprime el valor del atributo 'href'
print(enlace['class'])  # Imprime el valor del atributo 'class'
# Out:
# https://www.ejemplo.com
# ['enlace-principal']
