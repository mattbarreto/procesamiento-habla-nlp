# %% [markdown]
# ## Variables

# %% [markdown]
# Es un espacio de memoria donde guardamos un dato, y a la vez, ese espacio de memoria recibe un nombre (identificador).
#
# 1 - El nombre no puede empezar con un número
#
# 2 - No se permite el uso de guiones medios
#
# 3 - No se permite el uso de espacios
#
# 4 - No podemos utilizar palabras reservadas

# %%
# Variable que contiene un elemento del conjunto de números enteros (int).
a = 15
print(a)

# %%
# Imprimir el tipo de dato de las variable anteriormente creada
type(a)

# %%
# Variable que contiene un número decimal (float)

b = 15.3
print(b)

# %%
type(b)

# %%
# Variable que contiene una cadena de caracteres o string (str)
c = 'Argentina'
d = '14'

# %%
# Imprimir los tipos de datos de las variables anteriormente creadas


#type(c) # Comprobar type(d) para verificar que también es str por estar entre ''
type(d)

# %% [markdown]
# Operaciones entre variables (aritméticas,relacionales, de asignación y operaciones lógicas )

# %% [markdown]
# ## Aritméticas

# %%
var1 = 15
var2 = 20
var3 = 30

suma = var1 + var2
print(suma)

# %%
15 + 20

# %%
resta = var3 - var2
print(resta)

# %%
multi = var1 * var2
print(multi)

# %%
# división (cociente)
div = var3 / var2
print(div)
# división (parte entera)
div2 = var3 // var2
print(div2)

# %%
suma = 4+5
print(suma)

# %%
# Obtener resto
resto = var3 % var2 # (30 módulo 20 = 10)
print(resto)

# %% [markdown]
# # Relacionales

# %%
var1 = 15
var2 = 20
var3 = 40

# %%
(var1==var2)

# %%
var1!=var2

# %%
var1>var2

# %%
var3>=var2

# %% [markdown]
# # De asignación

# %%
x=2
x+=2 #Es lo mismo que x = x + 2
print(x)

# %% [markdown]
# # Operaciones con Strings

# %%
# Concatenación
a = 'Hola '
b = 'Mundo'
c= a + b
print(c)
# Out:
# Hola Mundo

# %%
# Multiplicación
frase = a * 3
print(frase)
# Out:
# Hola Hola Hola

# %% [markdown]
# # Operaciones lógicas

# %%
var1 = 10
var2 = 20
var3 = 30

# %%
var1 > 0 and var2 <100
# Out:
# True

# %%
var1 > 0 or var2 >100
# Out:
# True

# %% [markdown]
# ### Resumen

# %%
# Define una variable de tipo texto
texto = "¡Hola, mundo!"

# Define una variable de tipo entero
entero = 10

# Define una variable de tipo decimal
decimal = 1.23

# Define una variable de tipo lista
lista_numeros = [1, 2, 3]

# Define una variable de tipo tupla
tupla_numeros = (1, 2, 3)

# Define una variable de tipo diccionario
diccionario = {"clave1": 1, "clave2": 2}

# Define una variable de tipo conjunto
conjunto_numeros = {1, 2, 3}

# %% [markdown]
# # Convertir tipos de datos(casting)

# %%
edad = int(input('Ingresa tu edad'))
print(edad)
# Out:
# Ingresa tu edad20
# 20

# %%
type(edad)
# Out:
# int

# %%
(edad) * 3
# Out:
# 60

# %% [markdown]
# # Condicionales if, elif, else

# %%
# Comparando valor ingresado
a = int(input('Ingrese un número '))
if (a < 0):
    print('El número es menor a cero')
elif (a > 0):
    print('El número es mayor a cero')
else:
    print('El número es igual a cero')
# Out:
# Ingrese un número 0
# El número es igual a cero

# %%
# Comparando tipo de datos
a = 10
b = 'pintura'
if (type(a) == type(b)):
    print('a y b son del mismo tipo de dato')
else:
    print('a y b son de tipos de dato diferentes')
# Out:
# a y b son de tipos de dato diferentes

# %% [markdown]
# # Ciclos for y while

# %% [markdown]
# El **ciclo for** se usa cuando sabes de antemano cuántas veces deseas ejecutar un bloque de código, o cuando necesitas iterar sobre una secuencia de elementos (como una lista, una cadena, un rango, etc.).

# %%
## Comprobar si números son pares o impares

for i in range(1, 21):
    if (i % 2 == 0):
        print('El número ',i, ' es par')
    else:
        print('El número ',i, ' es impar')
# Out:
# El número  1  es impar
# El número  2  es par
# El número  3  es impar
# El número  4  es par
# El número  5  es impar
# El número  6  es par
# El número  7  es impar
# El número  8  es par
# El número  9  es impar
# El número  10  es par
# El número  11  es impar
# El número  12  es par
# El número  13  es impar
# El número  14  es par
# El número  15  es impar
# El número  16  es par
# El número  17  es impar
# El número  18  es par
# El número  19  es impar
# El número  20  es par

# %% [markdown]
# El **ciclo while** se usa cuando quieres repetir un bloque de código mientras una condición sea verdadera. Es útil cuando no sabes de antemano cuántas veces se ejecutará el ciclo, sino que depende de una condición que puede cambiar durante la ejecución del ciclo.

# %%
# El mismo ejemplo anterior, pero resuelto con un ciclo while
# resuelto con while

i=1
while (i <= 20):
    if (i % 2 == 0):
        print('El numero' ,i, 'es par')
    else:
        print('El numero' ,i, 'es impar')
    i = i + 1
# Out:
# El numero 1 es impar
# El numero 2 es par
# El numero 3 es impar
# El numero 4 es par
# El numero 5 es impar
# El numero 6 es par
# El numero 7 es impar
# El numero 8 es par
# El numero 9 es impar
# El numero 10 es par
# El numero 11 es impar
# El numero 12 es par
# El numero 13 es impar
# El numero 14 es par
# El numero 15 es impar
# El numero 16 es par
# El numero 17 es impar
# El numero 18 es par
# El numero 19 es impar
# El numero 20 es par

# %% [markdown]
# Sentencias break y continue

# %%
# break en ciclo for

cadena = 'Python'
for letra in cadena:
    if letra == 'h':
        print("Se encontró la h")
        break
    print(letra)
# Out:
# P
# y
# t
# Se encontró la h

# %%
# break en ciclo while

x = 5
while x > 0:
    x -= 1 # x = x - 1
    print(x)
    if x == 0:
        break
print("Fin del bucle")
# Out:
# 4
# 3
# 2
# 1
# 0
# Fin del bucle

# %%
# continue
cadena = 'Python'
for letra in cadena:
    if letra == 'P' or letra == 'o':
        continue

    print(letra)
# Out:
# y
# t
# h
# n
